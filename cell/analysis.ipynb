# %% [markdown]
# Load packages

# %%
import matplotlib
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json

# %% [markdown]
# Experiment Directory

# %%
current_dir = os.getcwd()
experiment_name = '1000mV_Sample00'
experiment_dir = current_dir + '/sort/' + experiment_name +  '/'

# %% [markdown]
# ## Single Cell Analysis

# %% [markdown]
# Load Cell directory

# %%
cell_number_to_analysis = 5
cell_dir = experiment_dir + '/' + 'cell_' + str(cell_number_to_analysis) + '.json'

# %% [markdown]
# Load Cell

# %%
cell_df = pd.read_json(cell_dir)

# %%
print(cell_df.head())
# Out:
#                                               frames
# 0  {'frame': 2, 'ID': 8, 'xmin': 17, 'ymin': 329,...
# 1  {'frame': 2, 'ID': 8, 'xmin': 17, 'ymin': 329,...
# 2  {'frame': 3, 'ID': 8, 'xmin': 16, 'ymin': 321,...
# 3  {'frame': 4, 'ID': 8, 'xmin': 13, 'ymin': 312,...
# 4  {'frame': 5, 'ID': 8, 'xmin': 9, 'ymin': 306, ...

# %%
print(cell_df['frames'])
# Out:
# 0       {'frame': 2, 'ID': 8, 'xmin': 17, 'ymin': 329,...
# 1       {'frame': 2, 'ID': 8, 'xmin': 17, 'ymin': 329,...
# 2       {'frame': 3, 'ID': 8, 'xmin': 16, 'ymin': 321,...
# 3       {'frame': 4, 'ID': 8, 'xmin': 13, 'ymin': 312,...
# 4       {'frame': 5, 'ID': 8, 'xmin': 9, 'ymin': 306, ...
#                               ...
# 4074    {'frame': 4075, 'ID': 32958, 'xmin': 99, 'ymin...
# 4075    {'frame': 4076, 'ID': 32958, 'xmin': 98, 'ymin...
# 4076    {'frame': 4077, 'ID': 32958, 'xmin': 97, 'ymin...
# 4077    {'frame': 4078, 'ID': 33187, 'xmin': 146, 'ymi...
# 4078    {'frame': 4079, 'ID': 32958, 'xmin': 93, 'ymin...
# Name: frames, Length: 4079, dtype: object

# %%
print(type(cell_df['frames']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(cell_df['frames'].iloc[1])
# Out:
# {'frame': 2, 'ID': 8, 'xmin': 17, 'ymin': 329, 'xmax': 27, 'ymax': 357, 'remove': False, 'x': 22.0, 'y': 343.0, 'velocity': 9.61769203083567}

# %%
print(type(cell_df['frames'].iloc[1]))
# Out:
# <class 'dict'>

# %%
print((cell_df['frames'].iloc[1])['x'])
print((cell_df['frames'].iloc[1])['y'])
# Out:
# 22.0
# 343.0

# %%
# Create scatter plot using a for loop
plt.figure(figsize=(10, 6))
# Define colormap
cmap = plt.get_cmap('viridis')
norm = plt.Normalize(0, 4000)
for i in range(4000):
    x = cell_df['frames'].iloc[i]['x']
    y = cell_df['frames'].iloc[i]['y']
    plt.scatter(x, y, color=cmap(norm(i)), alpha=0.6, edgecolors='w', linewidth=0.5)

plt.title('Scatter plot of the cell trajectory')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
